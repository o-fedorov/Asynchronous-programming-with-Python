# %% [markdown]
# # Asynchronous programming with Python
# ## Module 2
#
# ### Agenda:
#
# * Evolution of asynchronous frameworks.
# * Meet Trio, a friendly Python library for async concurrency and I/O.
# * Some practice.

# %% [markdown]
# ## Evolution of asynchronous frameworks

# %% [markdown]
# Long, long time ago...
#
# 🔵 ◀︎ 2001 - [Deffered](https://twistedmatrix.com/documents/16.2.0/core/howto/defer.html#visual-explanation) object is introduced with Twisted library.
# ⼁
# 🔵 ◀︎ 2003 - [PEP-255](https://www.python.org/dev/peps/pep-0255): add `yeld` keyword.  Twisted gets generator-based coroutines.
# ⼁
# ⼁
# 🔵 ◀︎ 2006 - [PEP-342](https://www.python.org/dev/peps/pep-342) add `send` and `throw` methods to generator.  Coroutines made simpler.
# ⼁
# ⼁
# ⼁
# ⼁
# ⼁
# 🔵 ◀︎ 2012 - [PEP-380](https://www.python.org/dev/peps/pep-380) add `yield from` construction.  Coroutines performance is improved.
# ⼁
# 🔵 ◀︎ 2014 - [PEP-3156](https://www.python.org/dev/peps/pep-3156) add `asyncio` to Python 3.4.  Coroutines are offitially a part of the standard library.
# 🔵 ◀︎ 2015 - [PEP-492](https://www.python.org/dev/peps/pep-492) add `async` and `await` syntax.  Coroutines are more readable.
# 🔵 ◀︎ 2016 - More syntax updates: asynchronous generators, asynchronous comprehensions.
# ⼁
# ⼁
# ⼁
# ⼁
# …
#
# 20 years after introducing `Deffered`s, asyncio still uses [Deferred-like objects](https://docs.python.org/3/library/asyncio-task.html#awaitables) to run.

# %% [markdown]
# ---
# ***And Now for Something Completely Different***

# %% [markdown]
# …
# ⼁
# 🟣 ◀︎ 2015 - [David Beazley](https://www.dabeaz.com/) introduced [Curio](https://github.com/dabeaz/curio), the next-level\*, coroutine-only asynchronous library.
# ⼁
# 🟣 ◀︎ 2017 - [Nathaniel Smith](https://vorpus.org/) brought ideas from `Curio` to his new [Trio](https://trio.readthedocs.io/en/stable/index.html) library, implementing structured concurrency\*\*.
# ⼁
# …

# %% [markdown]
# ---
#
# \* From the description of Curio:
#
# Curio strictly separates asynchronous code from synchronous code. Specifically, *all* functionality related to the asynchronous environment utilizes "async/await" features and syntax--without exception. Moreover, interactions between async and sync code is carefully managed through a small set of simple mechanisms such as events and queues. As a result, Curio is small, fast, and significantly easier to reason about.
#
# <div align="right">
#     – <a href="https://github.com/dabeaz/curio#curio-is-differen">https://github.com/dabeaz/curio#curio-is-differen</a>
# </div>
#
#
# \*\* **Structured concurrency** is a programming paradigm aimed at improving the clarity, quality, and development time of a computer program by using a structured approach to concurrent programming. The core concept is the encapsulation of concurrent threads of execution (here encompassing kernel and userland threads and processes) by way of control flow constructs that have clear entry and exit points and that ensure all spawned threads have completed before exit.
#
# <div align="right">
#     – <a href="https://en.wikipedia.org/wiki/Concurrent_computing">Wikipedia / Concurrent computing </a>
# </div>

# %% [markdown]
# ## Meet Trio
#
# The examples below are taken from [Trio's documentation](https://trio.readthedocs.io/en/stable/).
#
# You may also check out the [official tutorial](https://trio.readthedocs.io/en/stable/tutorial.html), it's nice.

# %% [markdown]
# First, install [trio](https://trio.readthedocs.io/en/stable/)
# and [asks](https://asks.readthedocs.io/en/latest/index.html)

# %%
# !pip install trio asks
# Out:
# Requirement already satisfied: trio in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (0.18.0)
# Requirement already satisfied: asks in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (2.4.12)
# Requirement already satisfied: h11 in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (from asks) (0.12.0)
# Requirement already satisfied: async_generator in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (from asks) (1.10)
# Requirement already satisfied: anyio~=2.0 in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (from asks) (2.2.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (from anyio~=2.0->asks) (1.2.0)
# Requirement already satisfied: typing-extensions in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (from anyio~=2.0->asks) (3.7.4.3)
# Requirement already satisfied: idna>=2.8 in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (from anyio~=2.0->asks) (3.1)
# Requirement already satisfied: attrs>=19.2.0 in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (from trio) (20.3.0)
# Requirement already satisfied: outcome in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (from trio) (1.1.0)
# Requirement already satisfied: sortedcontainers in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (from trio) (2.3.0)

# %% [markdown]
# ### Sample program
# Trio programs are like
#
# ![piping async code with Trio](../images/piping-async-code-trio.png)

# %%
import trio

async def double_sleep(x):
    print("started! sleeping now...")
    await trio.sleep(2 * x)
    print("exiting!")

trio.run(double_sleep, 3)  # does nothing for 6 seconds then returns
# Out:
# started! sleeping now...
# exiting!

# %% [markdown]
# ### Nursery
# If you want to spawn child tasks, you should be a responsible parent.

# %%
import trio

async def child1():
    print("  child1: started! sleeping now...")
    await trio.sleep(1)
    print("  child1: exiting!")


async def child2():
    print("  child2: started! sleeping now...")
    await trio.sleep(2)
    print("  child2: exiting!")


async def parent():
    print("parent: started!")
    async with trio.open_nursery() as nursery:
        print("parent: spawning child1...")
        nursery.start_soon(child1)

        print("parent: spawning child2...")
        nursery.start_soon(child2)

        print("parent: waiting for children to finish...")
        # -- we exit the nursery block here --
    print("parent: all done!")


trio.run(parent)
# Out:
# parent: started!
# parent: spawning child1...
# parent: spawning child2...
# parent: waiting for children to finish...
#   child1: started! sleeping now...
#   child2: started! sleeping now...
#   child1: exiting!
#   child2: exiting!
# parent: all done!

# %% [markdown]
# The children *never* leave the nursery scope, and this is awesome.
#
# ![baby ducks under their mother](../images/baby-ducks.png)
#
# ---

# %% [markdown]
# ### Tasks communication
# Use [`trio.open_memory_channel`](https://trio.readthedocs.io/en/stable/reference-core.html#using-channels-to-pass-values-between-tasks)
# to create a pair of send and receive channels.

# %%
import trio


async def main():
    async with trio.open_nursery() as nursery:
        # Open a channel:
        send_channel, receive_channel = trio.open_memory_channel(0)
        # Start a producer and a consumer, passing one end of the channel to
        # each of them:
        nursery.start_soon(producer, send_channel)
        nursery.start_soon(consumer, receive_channel)


async def producer(send_channel):
    async with send_channel:
        # Producer sends 3 messages
        for i in range(3):
            # The producer sends using 'await send_channel.send(...)'
            print(f"sending a message: {i}")
            await send_channel.send(f"message {i}")


async def consumer(receive_channel):
    async with receive_channel:
        # The consumer uses an 'async for' loop to receive the values:
        async for value in receive_channel:
            print(f"got value {value!r}")


trio.run(main)
# Out:
# sending a message: 0
# got value 'message 0'
# sending a message: 1
# sending a message: 2
# got value 'message 1'
# got value 'message 2'

# %% [markdown]
# ##### Some practice
#
# **1. Update the code above to have two children processing the messages concurrently.
# Pass some ID to the `consumer` function to be able to
# tell which child picked which message.**
#
# **2. What happens if you have two producers as well?
# Chances are you will occasionally get some errors.**
#
# **2.1. Fix the errors by passing `send_channel.clone()` to producers.**
#
# **3. Pass `receive_channel.clone()` to the children to have
# fan-out behaviour.**

# %% [markdown]
# 👉 *In general you should use unbuffered memory channels by passing `0` to `trio.open_memory_channel`.
# Buffer should be defined only if it is required to unblock the producer.
# For details see the [Trio documentation](https://trio.readthedocs.io/en/stable/reference-core.html#buffering-in-channels).*👈

# %% [markdown]
# ### Adwanced topic: cancellation scope
#
# #### A simple timeout example.
# Try to run the code below multiple times.

# %%
from random import randint

import asks
import trio

async def main():
    with trio.move_on_after(5):
        result = await asks.get(f"https://httpbin.org/delay/{ randint(1, 10) }")
        print("result is", result)
    print("with block finished")


trio.run(main)
# Out:
# with block finished

# %% [markdown]
# #### Nested scopes
# How do you think, what the code below will print out?

# %%
import trio

async def main():
    print("starting...")
    with trio.move_on_after(2):
        with trio.move_on_after(4):
            await trio.sleep(5)
            print("sleep finished without error")
        print("move_on_after(4) finished without error")
    print("move_on_after(2) finished without error")

trio.run(main)
# Out:
# starting...
# move_on_after(2) finished without error

# %% [markdown]
# ##### Some practice
#
# **1. Change the values passed to `move_on_after` so that the inner one takes effect.**
#
# 👉 *You can get `trio.CancelScope` instance using
# `with trio.move_on_after(...) as cancel_scope:`.
# Setting `cleanup_scope.shield = True` shields the cancel scope from
# the upstream cancellation.
# Setting `cleanup_scope.deadline += N` increases the deadline by N seconds.*👈
#
# **2. Instead of changing the values of `move_on_after`,
# update one of the cancellation scope instances so that the
# inner one takes effect.**

# %% [markdown]
# #### Shielding
# How do you think, what the code below will print out?

# %%
import trio

async def main():
    with trio.move_on_after(2):
        # This request blocks for 4 seconds before returning
        try:
            print("Starting a blocking request.")
            await asks.get(f"https://httpbin.org/delay/3")
            print("The first request succeeded.")
        except trio.Cancelled:
            print("The first request timed out, try with a smaller delay.")
            await asks.get(f"https://httpbin.org/delay/1")
            print("The second request succeeded.")

    print("Done.")


trio.run(main)
# Out:
# Starting a blocking request.
# The first request timed out, try with a smaller delay.
# Done.

# %% [markdown]
# ##### Some practice
#
# **Update the code so that the second request succeeds in case the
# first one failed.**

# %% [markdown]
# ### Testing
# For testing Trio with `pytest` use
# [pytest-trio](https://pytest-trio.readthedocs.io/en/stable/index.html).
#
# First, install the test libraries.

# %%
# !pip install pytest pytest-trio ipytest
# Out:
# Requirement already satisfied: pytest in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (6.2.3)
# Requirement already satisfied: pytest-trio in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (0.7.0)
# Requirement already satisfied: ipytest in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (0.9.1)
# Requirement already satisfied: ipython in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (from ipytest) (7.22.0)
# Requirement already satisfied: packaging in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (from ipytest) (20.9)
# Requirement already satisfied: pluggy<1.0.0a1,>=0.12 in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (from pytest) (0.13.1)
# Requirement already satisfied: importlib-metadata>=0.12 in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (from pytest) (3.10.1)
# Requirement already satisfied: toml in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (from pytest) (0.10.2)
# Requirement already satisfied: attrs>=19.2.0 in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (from pytest) (20.3.0)
# Requirement already satisfied: iniconfig in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (from pytest) (1.1.1)
# Requirement already satisfied: py>=1.8.2 in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (from pytest) (1.10.0)
# Requirement already satisfied: zipp>=0.5 in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (from importlib-metadata>=0.12->pytest) (3.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (from importlib-metadata>=0.12->pytest) (3.7.4.3)
# Requirement already satisfied: outcome in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (from pytest-trio) (1.1.0)
# Requirement already satisfied: async-generator>=1.9 in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (from pytest-trio) (1.10)
# Requirement already satisfied: trio>=0.15.0 in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (from pytest-trio) (0.18.0)
# Requirement already satisfied: idna in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (from trio>=0.15.0->pytest-trio) (3.1)
# Requirement already satisfied: sniffio in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (from trio>=0.15.0->pytest-trio) (1.2.0)
# Requirement already satisfied: sortedcontainers in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (from trio>=0.15.0->pytest-trio) (2.3.0)
# Requirement already satisfied: pickleshare in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (from ipython->ipytest) (0.7.5)
# Requirement already satisfied: appnope in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (from ipython->ipytest) (0.1.2)
# Requirement already satisfied: pygments in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (from ipython->ipytest) (2.8.1)
# Requirement already satisfied: jedi>=0.16 in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (from ipython->ipytest) (0.18.0)
# Requirement already satisfied: pexpect>4.3 in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (from ipython->ipytest) (4.8.0)
# Requirement already satisfied: traitlets>=4.2 in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (from ipython->ipytest) (5.0.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (from ipython->ipytest) (3.0.18)
# Requirement already satisfied: decorator in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (from ipython->ipytest) (5.0.7)
# Requirement already satisfied: backcall in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (from ipython->ipytest) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (from ipython->ipytest) (41.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (from jedi>=0.16->ipython->ipytest) (0.8.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (from pexpect>4.3->ipython->ipytest) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->ipytest) (0.2.5)
# Requirement already satisfied: ipython-genutils in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (from traitlets>=4.2->ipython->ipytest) (0.2.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/ofedoro/src/Asynchronous-programming-with-Python/.venv/lib/python3.7/site-packages (from packaging->ipytest) (2.4.7)

# %%
# Some magic to enable tests in the notebook
import ipytest
ipytest.autoconfig(clean=True, addopts=("--capture=tee-sys", "-qq"))

# %% [markdown]
# #### Creating a test

# %%
# %%run_pytest
# import pytest
# import trio
#
#
# async def double_sleep(x):
#     sleep_for = 2 * x
#     print("started! sleeping now...")
#     await trio.sleep(sleep_for)
#     print("exiting!")
#     return sleep_for
#
#
# @pytest.mark.trio
# async def test_double_sleep():
#     assert await double_sleep(3) == 6
# Out:
# started! sleeping now...
# exiting!
# .                                                                        [100%]

# %% [markdown]
# 👉 *If you don't want to mark each test with `@pytest.mark.trio`, there
# are other ways to enable Trio mode globally,
# see [the documentation](https://pytest-trio.readthedocs.io/en/stable/reference.html#trio-mode).*👈

# %% [markdown]
# #### Mock clocks
# The test above can be speed up with an
# [autojump_clock](https://pytest-trio.readthedocs.io/en/stable/reference.html#built-in-fixtures)
# fixture.

# %%
# %%run_pytest
# @pytest.mark.trio
# async def test_double_sleep(autojump_clock):
#     assert await double_sleep(3) == 6
#     assert trio.current_time() == 6
# Out:
# started! sleeping now...
# exiting!
# .                                                                        [100%]

# %% [markdown]
# 👉 *If you need more control on the clock skews, you can use
# a [mock_clock](https://pytest-trio.readthedocs.io/en/stable/reference.html#built-in-fixtures).*👈

# %% [markdown]
# #### Checking checkpoints
# You should always ensure that your code have enough Trio checkpoints
# so that context switching and cancellation mechanizm works.
#
# Consider this example.

# %%
# %%run_pytest
#
# async def broken_double_sleep(x):
#     sleep_for = 2 * x
#     print("started! sleeping now...")
#
#     if sleep_for % 2:
#         # This will work only if x is a fractional number
#         await trio.sleep(sleep_for)
#
#     print("exiting!")
#     return sleep_for
#
#
# @pytest.mark.trio
# async def test_broken_double_sleep():
#     assert await broken_double_sleep(3) == 6
# Out:
# started! sleeping now...
# exiting!
# .started! sleeping now...
# exiting!
# F                                                                       [100%]
# =================================== FAILURES ===================================
# ___________________________ test_broken_double_sleep ___________________________
#
# value = <trio.Nursery object at 0x10cf677d0>
#
#     async def yield_(value=None):
# >       return await _yield_(value)
#
# ../.venv/lib/python3.7/site-packages/async_generator/_impl.py:106:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# ../.venv/lib/python3.7/site-packages/async_generator/_impl.py:99: in _yield_
#     return (yield _wrap(value))
# <ipython-input-14-971b9d2388f9>:16: in test_broken_double_sleep
#     assert await broken_double_sleep(3) == 6
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# self = <contextlib._GeneratorContextManager object at 0x10cf67590>, type = None
# value = None, traceback = None
#
#     def __exit__(self, type, value, traceback):
#         if type is None:
#             try:
# >               next(self.gen)
# E               AssertionError: assert_checkpoints block did not yield!
#
# ../../../.pyenv/versions/3.7.6/lib/python3.7/contextlib.py:119: AssertionError
# ----------------------------- Captured stdout call -----------------------------
# started! sleeping now...
# exiting!
# =========================== short test summary info ============================
# FAILED tmpg5zy__8a.py::test_broken_double_sleep - AssertionError: assert_chec...

# %% [markdown]
# The test passes.  Now, try wrapping the last line with `with trio.testing.assert_checkpoints():`.

# %% [markdown]
# #### References
# For more useful test utilities refer to
# [pytest-trio](https://pytest-trio.readthedocs.io/en/stable/index.html)
# and [trio.testing](https://trio.readthedocs.io/en/stable/reference-testing.html#module-trio.testing)
# documentation.
#
# ## Conclusion
# Trio helps to write code with a focus on usability and correctness.
# It makes it a great framework to create your first asynchronous
# application.
#
# The downside of Trio is that it is not as "mainstream" as
# `asyncio`.  Even though Trio ecosystem is robust, you may find it
# hard to get libraries for the cases where `asyncio` is already used.
